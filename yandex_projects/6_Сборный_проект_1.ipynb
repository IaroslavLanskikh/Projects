# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
# Спасибо, что поправил, оставил несколько небольших комментариев. Удачи в следующих спринтах :)</div>

# %% [markdown]
# # Описание проекта
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# # Описание данных
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
# - Данные за 2016 год могут быть неполными.

# %% [markdown]
# # <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Привет! Меня зовут Алексей Тюрин, я буду делать ревью твоей работы. Давай будем общаться на «ты».
#
# У тебя хорошая, аккуратная работа 👍. В ней всё здорово, нужно только скорректировать актуальный период и посмотерть на распределение продаж для игр без рейтинга по регионам. Можешь посмотерть остальыне комментарии и задать вопросы, если будут :)
#
# ---
# Комментарии делятся на 3 группы:
#
# Зелёным цветом отмечены комментарии, либо подчёркивающие удачные решения, либо содержащие какую-то дополнительную информацию или советы, они формально не требуют правки, но правки приветствуются. Выделены они так:
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Тут текст
# </div>
#
# Жёлтым цветом выделены правки, которые желательны:
#
# <div class="alert alert-warning"; style="border-left: 7px solid yellow" >
# <h3>!! Комментарий ревьюера</h3>
#
# Тут текст
# </div>
#
# Красным выделены правки, которые обязательны
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <h3>👀 Комментарий ревьюера</h3>
#
# Тут текст
# </div>
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если оставляешь комментарии на какой-то итерации ревью, пиши что-то вроде `комментарий студента V.{номер итерации}`
# </div>
#
# Цвет можно сделать, например, так
#
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>Комментарий студента</h3>
# Ревьюер душнила :)
# </div>
#
# Или так:
#
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab;border-left:7px solid #2e00ab">
# <h3>Комментарий студента </h3>
#     ...
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
#         Это вам кто-то из студентов такой комментарий оставил?<br>
#          "Ревьюер душнила :)"
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
# Нет, сам придумал, пока так ещё никто не писал :)</div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Здорово, что все импорты собраны в самом начале, так сразу понятно, какие у проекта зависимости 👍</div>

# %% [markdown]
# Цель проекта: Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании в 2017 году. </br>
# Для этого мне дали данные о продажах игр до 2016 года.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Можно больше про контекст проекта добавить, т.е. написать про интернет-магазин и т.п. Дополнительно можно сопроводить введение содержанием из гиперссылок на разделы работы, например:
# </div>

# %% [markdown]
# 1. [Предобработка](#preprocessing)
# 2. [Анализ](#analysis)
# 3. [Портрет пользователя по регионам](#region)
# 4. [Проверка гипотез](#hypothesis)

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Во время написания проекта у самого появлялась мысль, что не очень удобно всё листать снизу вверх.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
# Есть расширения типа TableOfContents, оно само такое делает, но если пунктов немного, то проще руками
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Я для этого в ячейку с заголовком добавил
#
# ```python
# <a id="preprocessing"> </a>
# # Шаг 2. Подготовьте данные
#
# ```
# </div>

# %% [markdown]
# # Шаг 1. Откройте файл с данными и изучите общую информацию

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid yellow" >
# <h3>!! Комментарий ревьюера</h3>
#
# Здорово, что делаешь проект локально, но на сервере твоих локальных путей нет, а твоя задача сделать так, чтобы проект работал на сервере Практикума, поэтому в следующий раз указывай, пожалуйста, пути так, чтобы их не надо было править. Я ниже поправил.
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Я сам об этом вспомнил через секунду после отправки файла!
#     Хотел поменять, но возникли какие-то проблемы с загрузкой, загрузить новый не смог. Как я понял из-за того, что проект уже был взят на ревью. Постараюсь не забывать, сразу писать через try: except:
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# > загрузить новый не смог. Как я понял из-за того, что проект уже был взят на ревью.
#
# Да, возможно, обычно есть возможность отредактировать то, что отправлено
# </div>

# %%
try:
    data = pd.read_csv(r'C:\Users\berya\Downloads\Project_Module_1.csv')
except FileNotFoundError as e:
    print(repr(e))
    data = pd.read_csv('/datasets/games.csv')
# Out:
# FileNotFoundError(2, 'No such file or directory')

# %%
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <a id="preprocessing"> </a>
# # Шаг 2. Подготовьте данные

# %% [markdown]
# ### Замените названия столбцов (приведите к нижнему регистру);

# %%
data.columns = data.columns.str.lower()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Хороший способ 👍</div>

# %% [markdown]
# ### Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;

# %% [markdown]
# Меняем тип object столбца user_score на float.
# Не получилось, т.к. в столбце user_score есть 'tbd', методом 'google' узнал, что tbd = to be determined (будет определено).

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Да, такие значения обычно устанавливают, когда данныех недостаточно для подсчёта оценки, напрмиер</div>

# %%
data.query('user_score == "tbd"').groupby('year_of_release')['name'].count()
# Out:
# year_of_release
# 1997.0      1
# 1999.0      8
# 2000.0     43
# 2001.0     82
# 2002.0    192
# 2003.0     95
# 2004.0    107
# 2005.0    121
# 2006.0    124
# 2007.0    192
# 2008.0    326
# 2009.0    405
# 2010.0    331
# 2011.0    217
# 2012.0     24
# 2013.0     15
# 2014.0     21
# 2015.0     38
# 2016.0     34
# Name: name, dtype: int64

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
# Посчитаю в долях.
# </div>

# %%
(data.query('user_score == "tbd"').groupby('year_of_release')['name'].count() / \
    data.query('year_of_release > 1998 or year_of_release == 1997').groupby('year_of_release')['name'].count()).round(2)
# Out:
# year_of_release
# 1997.0    0.00
# 1999.0    0.02
# 2000.0    0.12
# 2001.0    0.17
# 2002.0    0.23
# 2003.0    0.12
# 2004.0    0.14
# 2005.0    0.13
# 2006.0    0.12
# 2007.0    0.16
# 2008.0    0.23
# 2009.0    0.28
# 2010.0    0.26
# 2011.0    0.19
# 2012.0    0.04
# 2013.0    0.03
# 2014.0    0.04
# 2015.0    0.06
# 2016.0    0.07
# Name: name, dtype: float64

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍 Чуть проще посчитать как:</div>

# %%
# Код ревьюера

data.groupby('year_of_release').agg({'user_score' : lambda x : (x == 'tbd').mean()})
# Out:
#                  user_score
# year_of_release
# 1980.0             0.000000
# 1981.0             0.000000
# 1982.0             0.000000
# 1983.0             0.000000
# 1984.0             0.000000
# 1985.0             0.000000
# 1986.0             0.000000
# 1987.0             0.000000
# 1988.0             0.000000
# 1989.0             0.000000
# 1990.0             0.000000
# 1991.0             0.000000
# 1992.0             0.000000
# 1993.0             0.000000
# 1994.0             0.000000
# 1995.0             0.000000
# 1996.0             0.000000
# 1997.0             0.003460
# 1998.0             0.000000
# 1999.0             0.023669
# 2000.0             0.122857
# 2001.0             0.170124
# 2002.0             0.231604
# 2003.0             0.122581
# 2004.0             0.140420
# 2005.0             0.128860
# 2006.0             0.123260
# 2007.0             0.160401
# 2008.0             0.228451
# 2009.0             0.284011
# 2010.0             0.263745
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# В целом выше ничего выбивающегося нет, но для периода с 2000 по 2011 почему-то таких значений больше</div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
# Видно, что доли довольно сильно разнятся. ОТ 0.02 до 0.28. Логических предположений зависимости года и количества значений "tbd" не имею. Впрочем, всё равно я заменяю все tbd на NaN.
# </div>

# %% [markdown]
# Из таблицы выше делаю вывод, что tbd в столбце user_score можно заменить на NaN.
# ПО логике, tbd должно быть только у игр 2016 года. Но тут это не так.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Возможно это намеренная порча датасета :) Чуть лучше смотреть не на абсолютное число таких значений, а на их долю для каждого года. Если доля будет одинаковой, то значения распределены случайно
#
# </div>

# %%
data.loc[data['user_score'] == "tbd",'user_score'] = None

# %%
data['user_score'] = data['user_score'].astype('float')

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Такие две строки можно заменить одной: `data['user_score'] = pd.to_numeric(data['user_score'], errors='coerce')` -- так всё, что не является числом, заменится на пропуск и приведётся нужный тип
# </div>

# %% [markdown]
# <code>
# data['year_of_release'] = data['year_of_release'].astype('int')
# </code>
# Ругается на NaN, поменяю после удаления пропусков.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Да, тип `int` пропуски не поддерживает. В большинсте случае достаточно округлить значения и оставить `float`. Но здесь это приведёт к тому, что подписи на графиках будут с лишнми нулями, поэтому удалить такое небольшое число пропусков хорошее решение. Есть ещё тип `Int64`, он поддерживает пропуски, но с ним не всё работает. Например, корреляция через `corrwith`:</div>

# %%
# Код ревьюера

df_demo = pd.DataFrame({'col_1' : [1,2,4,np.nan], 'col_2' : [10,20,40,50]}).astype({'col_1' : 'Int64', 'col_2' : 'int'})

try:
    df_demo[['col_1']].corrwith(df_demo['col_2'])
except Exception as e:
    print(repr(e))
    
df_demo = df_demo.astype({'col_1' : 'float'})

df_demo[['col_1']].corrwith(df_demo['col_2'])
# Out:
# AttributeError("'float' object has no attribute 'shape'")
# col_1    1.0
# dtype: float64

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Увидел, понял!
# </div>

# %% [markdown]
# ### Удаление пропусков

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %% [markdown]
# Пойдём по порядку.

# %% [markdown]
# Удаляем строки с пропусками в name, всего 2 строки

# %%
data = data.dropna(subset=['name']).reset_index(drop=True)

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Заключил 'name' в []<br>
#     Буду проверять как запускается весь код в Практикуме. <br>
#     Хотел вставить сюда гиперссылку (ниже), но не работало.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# У меня работает гиперссылка</div>

# %% [markdown]
# 1. [Ещё заменил вот тут](#dropna)

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid yellow" >
# <h3>!! Комментарий ревьюера</h3>
#
# ещё твоё локально окружение должно совпалать с окружение в Практикуме, т.к. функции в разных версиях библиотеки ведут себя по-разному. Выше, например, код из-за этого не работает
#
#
# > ![image.png](attachment:image.png)
#
# В окружении Практикума версии библиотек такие
#
# ```python
#
# # This file may be used to create an environment using:
# # $ conda create --name <env> --file <this file>
# # platform: linux-64
# _libgcc_mutex=0.1=conda_forge
# _openmp_mutex=4.5=1_gnu
# abseil-cpp=20210324.2=h9c3ff4c_0
# absl-py=1.2.0=pypi_0
# alembic=1.6.5=pyhd8ed1ab_0
# anyio=3.2.1=py39hf3d152e_0
# argon2-cffi=20.1.0=py39h3811e60_2
# arrow-cpp=5.0.0=py39h3d6947c_1_cpu
# astunparse=1.6.3=pypi_0
# async_generator=1.10=py_0
# attrs=20.3.0=pypi_0
# aws-c-cal=0.5.11=h95a6274_0
# aws-c-common=0.6.2=h7f98852_0
# aws-c-event-stream=0.2.7=h3541f99_13
# aws-c-io=0.10.5=hfb6a706_0
# aws-checksums=0.1.11=ha31a3da_7
# aws-sdk-cpp=1.8.186=hb4091e7_3
# babel=2.9.1=pyh44b312d_0
# backcall=0.2.0=pyh9f0ad1d_0
# backports=1.0=py_2
# backports.functools_lru_cache=1.6.4=pyhd8ed1ab_0
# beautifulsoup4=4.9.3=pypi_0
# bleach=3.3.0=pyh44b312d_0
# blinker=1.4=py_1
# blis=0.7.8=pypi_0
# branca=0.5.0=pypi_0
# brotlipy=0.7.0=py39h3811e60_1001
# bzip2=1.0.8=h7f98852_4
# c-ares=1.17.1=h7f98852_1
# ca-certificates=2022.6.15=ha878542_0
# cachetools=5.2.0=pypi_0
# catalogue=2.0.8=pypi_0
# catboost=1.0.3=pypi_0
# certifi=2021.5.30=pypi_0
# certipy=0.1.3=py_0
# cffi=1.14.5=py39he32792d_0
# chardet=4.0.0=py39hf3d152e_1
# click=8.1.3=pypi_0
# conda=4.10.2=py39hf3d152e_0
# conda-package-handling=1.7.3=py39h3811e60_0
# configurable-http-proxy=4.4.0=node15_he6ea98c_0
# convertdate=2.4.0=pypi_0
# cryptography=3.4.7=py39hbca0aa6_0
# cycler=0.11.0=pypi_0
# cymem=2.0.6=pypi_0
# dawg-python=0.7.2=pypi_0
# debugpy=1.3.0=py39he80948d_0
# decorator=5.0.9=pyhd8ed1ab_0
# defusedxml=0.7.1=pyhd8ed1ab_0
# docopt=0.6.2=pypi_0
# en-core-web-sm=3.2.0=pypi_0
# entrypoints=0.3=pyhd8ed1ab_1003
# et-xmlfile=1.1.0=pypi_0
# filelock=3.8.0=pypi_0
# findspark=1.4.2=pypi_0
# flatbuffers=2.0.7=pypi_0
# folium=0.12.1.post1=pypi_0
# fuzzywuzzy=0.18.0=pypi_0
# gast=0.4.0=pypi_0
# gensim=4.1.2=pypi_0
# gflags=2.2.2=he1b5a44_1004
# glog=0.5.0=h48cff8f_0
# google-auth=2.11.0=pypi_0
# google-auth-oauthlib=0.4.6=pypi_0
# google-pasta=0.2.0=pypi_0
# greenlet=1.1.0=py39he80948d_0
# grpc-cpp=1.39.0=h36ce80c_1
# grpcio=1.47.0=pypi_0
# gspread=5.0.0=pypi_0
# h5py=3.7.0=pypi_0
# hijri-converter=2.2.4=pypi_0
# holidays=0.11.3.1=pypi_0
# huggingface-hub=0.9.1=pypi_0
# icu=68.1=h58526e2_0
# idna=2.10=pyh9f0ad1d_0
# importlib-metadata=4.6.1=py39hf3d152e_0
# ipykernel=6.0.1=py39hef51801_0
# ipython=7.25.0=py39hef51801_1
# ipython_genutils=0.2.0=py_1
# ipywidgets=7.6.3=pypi_0
# jedi=0.18.0=py39hf3d152e_2
# jinja2=3.0.1=pyhd8ed1ab_0
# joblib=1.1.0=pypi_0
# json5=0.9.5=pyh9f0ad1d_0
# jsonschema=3.2.0=pyhd8ed1ab_3
# jupyter=1.0.0=pypi_0
# jupyter-console=6.4.2=pypi_0
# jupyter-contrib-core=0.4.0=pypi_0
# jupyter-contrib-nbextensions=0.5.1=pypi_0
# jupyter-highlight-selected-word=0.2.0=pypi_0
# jupyter-latex-envs=1.4.6=pypi_0
# jupyter-nbextensions-configurator=0.5.0=pypi_0
# jupyter_client=6.1.12=pyhd8ed1ab_0
# jupyter_core=4.7.1=py39hf3d152e_0
# jupyter_server=1.9.0=pyhd8ed1ab_0
# jupyter_telemetry=0.1.0=pyhd8ed1ab_1
# jupyterhub=1.4.2=pypi_0
# jupyterlab=3.0.16=pyhd8ed1ab_0
# jupyterlab-widgets=3.0.2=pypi_0
# jupyterlab_pygments=0.1.2=pyh9f0ad1d_0
# jupyterlab_server=2.6.0=pyhd8ed1ab_0
# keras=2.7.0=pypi_0
# keras-preprocessing=1.1.2=pypi_0
# kiwisolver=1.4.4=pypi_0
# korean-lunar-calendar=0.2.1=pypi_0
# krb5=1.19.1=hcc1bbae_0
# langcodes=3.3.0=pypi_0
# ld_impl_linux-64=2.36.1=hea4e1c9_1
# libarchive=3.5.1=hccf745f_2
# libblas=3.9.0=11_linux64_openblas
# libbrotlicommon=1.0.9=h7f98852_5
# libbrotlidec=1.0.9=h7f98852_5
# libbrotlienc=1.0.9=h7f98852_5
# libcblas=3.9.0=11_linux64_openblas
# libclang=14.0.6=pypi_0
# libcurl=7.77.0=h2574ce0_0
# libedit=3.1.20191231=he28a2e2_2
# libev=4.33=h516909a_1
# libevent=2.1.10=hcdb4288_3
# libffi=3.3=h58526e2_2
# libgcc-ng=9.3.0=h2828fa1_19
# libgfortran-ng=12.1.0=h69a702a_16
# libgfortran5=12.1.0=hdcd56e2_16
# libgomp=9.3.0=h2828fa1_19
# libiconv=1.16=h516909a_0
# liblapack=3.9.0=11_linux64_openblas
# libnghttp2=1.43.0=h812cca2_0
# libopenblas=0.3.17=pthreads_h8fe5266_1
# libprotobuf=3.16.0=h780b84a_0
# libsodium=1.0.18=h36c2ea0_1
# libsolv=0.7.19=h780b84a_4
# libssh2=1.9.0=ha56f1ee_6
# libstdcxx-ng=9.3.0=h6de172a_19
# libthrift=0.14.2=he6d91bd_1
# libutf8proc=2.6.1=h7f98852_0
# libuv=1.41.1=h7f98852_0
# libxml2=2.9.12=h72842e0_0
# lightgbm=3.3.1=pypi_0
# llvmlite=0.39.0=pypi_0
# lxml=4.6.3=pypi_0
# lz4-c=1.9.3=h9c3ff4c_0
# lzo=2.10=h516909a_1000
# mako=1.1.4=pyh44b312d_0
# mamba=0.14.1=py39h951de11_0
# markdown=3.4.1=pypi_0
# markupsafe=2.1.1=pypi_0
# matplotlib=3.3.4=pypi_0
# matplotlib-inline=0.1.2=pyhd8ed1ab_2
# mistune=0.8.4=py39h3811e60_1004
# murmurhash=1.0.8=pypi_0
# nbclassic=0.3.1=pyhd8ed1ab_1
# nbclient=0.5.3=pyhd8ed1ab_0
# nbconvert=6.0.7=pypi_0
# nbformat=5.1.3=pyhd8ed1ab_0
# nbgrader=0.6.1=pypi_0
# ncurses=6.2=h58526e2_4
# nest-asyncio=1.5.1=pyhd8ed1ab_0
# nltk=3.6.1=pypi_0
# nodejs=15.14.0=h92b4a50_0
# notebook=6.4.0=pyha770c72_0
# numba=0.56.0=pypi_0
# numpy=1.20.1=pypi_0
# oauthlib=3.1.1=pyhd8ed1ab_0
# openpyxl=3.0.9=pypi_0
# openssl=1.1.1k=h7f98852_0
# opt-einsum=3.3.0=pypi_0
# orc=1.6.9=h58a87f1_0
# packaging=21.3=pypi_0
# pamela=1.0.0=py_0
# pandas=1.2.4=pypi_0
# pandoc=2.14.0.3=h7f98852_0
# pandocfilters=1.4.2=py_1
# parquet-cpp=1.5.1=2
# parso=0.8.2=pyhd8ed1ab_0
# pathy=0.6.2=pypi_0
# patsy=0.5.2=pypi_0
# pexpect=4.8.0=pyh9f0ad1d_2
# pickleshare=0.7.5=py_1003
# pillow=8.4.0=pypi_0
# pip=21.1.3=pyhd8ed1ab_0
# plotly=5.4.0=pypi_0
# preshed=3.0.7=pypi_0
# prometheus_client=0.11.0=pyhd8ed1ab_0
# prompt-toolkit=3.0.19=pyha770c72_0
# protobuf=3.19.4=pypi_0
# psycopg2-binary=2.9.2=pypi_0
# ptyprocess=0.7.0=pyhd3deb0d_0
# py4j=0.10.9.3=pypi_0
# pyarrow=5.0.0=py39h3ebc44c_1_cpu
# pyasn1=0.4.8=pypi_0
# pyasn1-modules=0.2.8=pypi_0
# pycosat=0.6.3=py39h3811e60_1006
# pycparser=2.20=pyh9f0ad1d_2
# pycurl=7.43.0.6=py39h72e3413_1
# pydantic=1.8.2=pypi_0
# pygments=2.9.0=pyhd8ed1ab_0
# pyjwt=2.1.0=pyhd8ed1ab_0
# pymeeus=0.5.11=pypi_0
# pymorphy2=0.9.1=pypi_0
# pymorphy2-dicts-ru=2.4.417127.4579844=pypi_0
# pymystem3=0.2.0=pypi_0
# pyod=0.9.5=pypi_0
# pyopenssl=20.0.1=pyhd8ed1ab_0
# pyparsing=2.4.7=pyh9f0ad1d_0
# pyrsistent=0.17.3=py39h3811e60_2
# pysocks=1.7.1=py39hf3d152e_3
# pyspark=3.0.2=pyh44b312d_0
# python=3.9.5=h49503c6_0_cpython
# python-dateutil=2.8.1=py_0
# python-editor=1.0.4=py_0
# python-graphviz=0.20.1=pypi_0
# python-json-logger=2.0.1=pyh9f0ad1d_0
# python_abi=3.9=2_cp39
# pytz=2021.1=pyhd8ed1ab_0
# pyyaml=6.0=pypi_0
# pyzmq=22.1.0=py39h37b5a0c_0
# qtconsole=5.3.2=pypi_0
# qtpy=2.2.0=pypi_0
# re2=2021.06.01=h9c3ff4c_0
# readline=8.1=h46c0cb4_0
# regex=2022.8.17=pypi_0
# reproc=14.2.1=h36c2ea0_0
# reproc-cpp=14.2.1=h58526e2_0
# requests=2.25.1=pyhd3deb0d_0
# requests-oauthlib=1.3.1=pypi_0
# requests-unixsocket=0.2.0=py_0
# rsa=4.9=pypi_0
# ruamel.yaml=0.17.10=py39h3811e60_0
# ruamel.yaml.clib=0.2.2=py39h3811e60_2
# ruamel_yaml=0.15.80=py39h3811e60_1004
# s2n=1.0.10=h9b69904_0
# sacremoses=0.0.53=pypi_0
# scikit-learn=0.24.1=pypi_0
# scipy=1.9.1=pypi_0
# seaborn=0.11.1=pypi_0
# send2trash=1.7.1=pyhd8ed1ab_0
# setuptools=49.6.0=py39hf3d152e_3
# six=1.16.0=pyh6c4a22f_0
# smart-open=5.2.1=pypi_0
# snappy=1.1.8=he1b5a44_3
# sniffio=1.2.0=py39hf3d152e_1
# soupsieve=2.3.2.post1=pypi_0
# spacy=3.2.0=pypi_0
# spacy-legacy=3.0.10=pypi_0
# spacy-loggers=1.0.3=pypi_0
# sqlalchemy=1.4.15=pypi_0
# sqlite=3.36.0=h9cd32fc_0
# srsly=2.4.4=pypi_0
# statsmodels=0.13.2=pypi_0
# tenacity=8.0.1=pypi_0
# tensorboard=2.10.0=pypi_0
# tensorboard-data-server=0.6.1=pypi_0
# tensorboard-plugin-wit=1.8.1=pypi_0
# tensorflow-cpu=2.7.0=pypi_0
# tensorflow-estimator=2.7.0=pypi_0
# tensorflow-io-gcs-filesystem=0.26.0=pypi_0
# termcolor=1.1.0=pypi_0
# terminado=0.10.1=py39hf3d152e_0
# testpath=0.5.0=pyhd8ed1ab_0
# thinc=8.0.17=pypi_0
# threadpoolctl=3.1.0=pypi_0
# tk=8.6.10=h21135ba_1
# tokenizers=0.10.3=pypi_0
# torch=1.10.0=pypi_0
# tornado=6.1=py39h3811e60_1
# tqdm=4.61.2=pyhd8ed1ab_1
# traitlets=5.0.5=py_0
# transformers=4.12.5=pypi_0
# typer=0.4.2=pypi_0
# typing-extensions=4.3.0=pypi_0
# tzdata=2021a=he74cb21_1
# urllib3=1.26.6=pyhd8ed1ab_0
# wasabi=0.10.1=pypi_0
# wcwidth=0.2.5=pyh9f0ad1d_2
# webencodings=0.5.1=py_1
# websocket-client=0.57.0=py39hf3d152e_4
# werkzeug=2.2.2=pypi_0
# wheel=0.36.2=pyhd3deb0d_0
# widgetsnbextension=3.5.2=pypi_0
# wrapt=1.14.1=pypi_0
# xgboost=1.5.1=pypi_0
# xlrd=2.0.1=pypi_0
# xmltodict=0.12.0=pypi_0
# xz=5.2.5=h516909a_1
# yaml=0.2.5=h516909a_0
# zeromq=4.3.4=h9c3ff4c_0
# zipp=3.5.0=pyhd8ed1ab_0
# zlib=1.2.11=h516909a_1010
# zstd=1.5.0=ha95c52a_0
#
# ```
# </div>

# %%
data.query('year_of_release.isna()').head()
# Out:
#                            name platform  year_of_release     genre  na_sales  \
# 183             Madden NFL 2004      PS2              NaN    Sports      4.26
# 377            FIFA Soccer 2004      PS2              NaN    Sports      0.59
# 456  LEGO Batman: The Videogame      Wii              NaN    Action      1.80
# 475  wwe Smackdown vs. Raw 2006      PS2              NaN  Fighting      1.57
# 609              Space Invaders     2600              NaN   Shooter      2.36
#
#      eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 183      0.26      0.01         0.71          94.0         8.5      E
# 377      2.36      0.04         0.51          84.0         6.4      E
# 456      0.97      0.00         0.29          74.0         7.9   E10+
# 475      1.02      0.00         0.41           NaN         NaN    NaN
# 609      0.14      0.00         0.03           NaN         NaN    NaN

# %% [markdown]
# Можно было бы восстановить год выпуска, т.к. есть названия игр.
# Но вручную это делать долго, а как это автоматизировать я не знаю, так что удалим.
# 270 строк, не так много

# %% [markdown]
# <a id='dropna'></a>
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Заключил 'year_of_release' в скобки.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍</div>

# %%
data = data.dropna(subset=['year_of_release']).reset_index(drop=True)

# %%
data['year_of_release'] = data['year_of_release'].astype('int')

# %% [markdown]
# Огромное количество пропусков в critic_score,user_score,rating. Нельзя их просто удалять. </br>
# Предполагаю, что игры на старых платформах могут быть без каких-либо рейтингов. Смотрим

# %%
ratio_list = []
for row in data.groupby('platform'):
    row_row = row[1]
    total = len(row_row)
    
    nan_count_critic_score = len(row_row.query('critic_score.isna()'))
    nan_count_user_score = len(row_row.query('user_score.isna()'))
    nan_count_rating = len(row_row.query('rating.isna()'))
    
    ratio_critic_score = nan_count_critic_score / total
    ratio_user_score = nan_count_user_score / total
    ratio_rating = nan_count_rating / total
    
    ratio_list.append({'platform':row[0],'ratio_critic_score':ratio_critic_score,'ratio_user_score':ratio_user_score, 'ratio_rating':ratio_rating})

# %%
ratio = pd.DataFrame(ratio_list)
ratio
# Out:
#    platform  ratio_critic_score  ratio_user_score  ratio_rating
# 0      2600            1.000000          1.000000      1.000000
# 1       3DO            1.000000          1.000000      1.000000
# 2       3DS            0.675781          0.666016      0.564453
# 3        DC            0.730769          0.730769      0.730769
# 4        DS            0.666195          0.758604      0.408298
# 5        GB            1.000000          1.000000      1.000000
# 6       GBA            0.469790          0.690506      0.366215
# 7        GC            0.193727          0.341328      0.156827
# 8       GEN            1.000000          1.000000      1.000000
# 9        GG            1.000000          1.000000      1.000000
# 10      N64            1.000000          1.000000      1.000000
# 11      NES            1.000000          1.000000      1.000000
# 12       NG            1.000000          1.000000      1.000000
# 13       PC            0.269592          0.211076      0.208986
# ...

# %%
group_year = data.groupby('platform').agg({'year_of_release' : ['min','max']}).reset_index()
group_year.columns = ['platform','year_first_game','year_last_game']
group_year
# Out:
#    platform  year_first_game  year_last_game
# 0      2600             1980            1989
# 1       3DO             1994            1995
# 2       3DS             2011            2016
# 3        DC             1998            2008
# 4        DS             1985            2013
# 5        GB             1988            2001
# 6       GBA             2000            2007
# 7        GC             2001            2007
# 8       GEN             1990            1994
# 9        GG             1992            1992
# 10      N64             1996            2002
# 11      NES             1983            1994
# 12       NG             1993            1996
# 13       PC             1985            2016
# 14     PCFX             1996            1996
# 15       PS             1994            2003
# 16      PS2             2000            2011
# 17      PS3             2006            2016
# 18      PS4             2013            2016
# 19      PSP             2004            2015
# ...

# %%
ratio_year = ratio.merge(group_year,on='platform')
ratio_year.sort_values('year_last_game')
# Out:
#    platform  ratio_critic_score  ratio_user_score  ratio_rating  \
# 0      2600            1.000000          1.000000      1.000000
# 9        GG            1.000000          1.000000      1.000000
# 22      SCD            1.000000          1.000000      1.000000
# 8       GEN            1.000000          1.000000      1.000000
# 11      NES            1.000000          1.000000      1.000000
# 1       3DO            1.000000          1.000000      1.000000
# 24     TG16            1.000000          1.000000      1.000000
# 12       NG            1.000000          1.000000      1.000000
# 14     PCFX            1.000000          1.000000      1.000000
# 23     SNES            1.000000          1.000000      1.000000
# 21      SAT            1.000000          1.000000      1.000000
# 25       WS            1.000000          1.000000      1.000000
# 5        GB            1.000000          1.000000      1.000000
# 10      N64            1.000000          1.000000      1.000000
# ...

# %% [markdown]
# Платформы, выпустившие последнюю игру до 2003 года вообще не имеют рейтинга. Убираем их.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Да, для старых платформ рейтингов совсем нет, но про оставльным пропуски распределны +- равномерно. Чуть проще посчитать можно так:
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Да, действительно проще.
# </div>

# %%
# Код ревьюера

data.groupby('platform').agg({'critic_score' : lambda x : x.isna().mean(), 'year_of_release' : ['min','max']})
# Out:
#          critic_score year_of_release
#              <lambda>             min   max
# platform
# 2600         1.000000            1980  1989
# 3DO          1.000000            1994  1995
# 3DS          0.675781            2011  2016
# DC           0.730769            1998  2008
# DS           0.666195            1985  2013
# GB           1.000000            1988  2001
# GBA          0.469790            2000  2007
# GC           0.193727            2001  2007
# GEN          1.000000            1990  1994
# GG           1.000000            1992  1992
# N64          1.000000            1996  2002
# NES          1.000000            1983  1994
# NG           1.000000            1993  1996
# PC           0.269592            1985  2016
# PCFX         1.000000            1996  1996
# PS           0.835294            1994  2003
# PS2          0.400564            2000  2011
# PS3          0.384380            2006  2016
# PS4          0.357143            2013  2016
# ...

# %%
more_2002 = ratio_year.loc[ratio_year['year_last_game'] > 2002 , 'platform']
data = data.query('platform in @more_2002')

# %%
data['year_of_release'].value_counts().sort_index()
# Out:
# 1985       2
# 1988       1
# 1992       5
# 1994      23
# 1995     101
# 1996     168
# 1997     194
# 1998     263
# 1999     221
# 2000     271
# 2001     461
# 2002     828
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     653
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# Name: year_of_release, dtype: int64

# %% [markdown]
# Очень мало игр за 1994 и меньше, убираем их.

# %%
data = data.query('year_of_release > 1994').reset_index(drop=True)

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       7337
# user_score         7857
# rating             5553
# dtype: int64

# %% [markdown]
# Определим среднее отношение critic_score к user_score, сгруппированные по жанрам.
# Заменим пропуски там, где есть хоть 1 значение в этих столбцах.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# После `\` стоит ставить отступ на следующей строке.
#
#
# В смысле анализа пропусков полезно было бы сгруппировать по регионам, чтобы проверить, зависят ли пропуски от региона, где у игры были продажи. Но для этого регион должен быть столбцом. Это можно осуществить так: https://www.statology.org/pandas-wide-to-long/#:~:text=2021%20by%20Zach-,Pandas%3A%20How%20to%20Reshape%20DataFrame%20from%20Wide%20to%20Long,and%20col2%2C%20col3%2C%20etc.
#
# Останется сгруппировать данные по столбцу с регионом, убрать нулевые продажи для каждого региона и посмотерть на долю пропусков для каждого
# </div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Попробую.
# </div>

# %%
df = pd.melt(data,id_vars=['name','platform','year_of_release','genre','critic_score','user_score','rating'],\
             value_vars=['na_sales','eu_sales','jp_sales','other_sales'],var_name='region',value_name='count')
df = df.query('count != 0')
df.groupby('region').agg({'critic_score': lambda x: x.isna().mean(),'user_score': lambda x: x.isna().mean()})
# Out:
#              critic_score  user_score
# region
# eu_sales         0.334620    0.367478
# jp_sales         0.613898    0.609253
# na_sales         0.353808    0.404879
# other_sales      0.353580    0.367564

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Видно, какой огромный процент пропусков в регионе JP. Хотя у остальных регионов тоже большой процент, больше 30%.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍 Вероятно источник мало знает про японские игры. Там, например, есть свой аналог ESRB рейтинга и возможно в источнике указан именно аналогичный рейтинг
# </div>

# %%
for row in data.groupby('genre'):
    row_row = row[1]
    name_genre = row[0]
    
    median = (row_row['user_score'] / row_row['critic_score']).median()
   
    data.loc[~(data['user_score'].isna()) & (data['critic_score'].isna()) & (data['genre'] == name_genre), 'critic_score'] = \
    data.loc[~(data['user_score'].isna()) & (data['critic_score'].isna()) & (data['genre'] == name_genre), 'user_score'] / median
    
    data.loc[(data['user_score'].isna()) & ~(data['critic_score'].isna()) & (data['genre'] == name_genre), 'user_score'] = \
    data.loc[(data['user_score'].isna()) & ~(data['critic_score'].isna()) & (data['genre'] == name_genre), 'critic_score'] * median

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# В идеале, чтобы так заменять, нужно проказать, что такое соотношение зависит от жанра игр. С точки зрения кода можно сделать так:
#
# ```python
#
# gr = data.groupby('genre')
# data['user_score'] = data['user_score'].fillna(gr['critic_score'].transform(lambda x : x / gr.get_group(x.name)['user_score']) * data['user_score])
#
# ```
#
# И аналогично для `critic_score`. Там, где одно из значений пропуск, в результате произведения тоже будет пропуск
# </div>

# %%
gr = data.groupby('genre')
data['user_score'] = data['user_score'].fillna(gr['critic_score'].transform(lambda x : x / gr.get_group(x.name)['user_score']) * data['user_score'])
data
# Out:
#                                 name platform  year_of_release       genre  \
# 0                         Wii Sports      Wii             2006      Sports
# 1                     Mario Kart Wii      Wii             2008      Racing
# 2                  Wii Sports Resort      Wii             2009      Sports
# 3              New Super Mario Bros.       DS             2006    Platform
# 4                           Wii Play      Wii             2006        Misc
# ...                              ...      ...              ...         ...
# 15311  Samurai Warriors: Sanada Maru      PS3             2016      Action
# 15312               LMA Manager 2007     X360             2006      Sports
# 15313        Haitaka no Psychedelica      PSV             2016   Adventure
# 15314               Spirits & Spells      GBA             2003    Platform
# 15315            Winning Post 8 2016      PSV             2016  Simulation
#
# ...

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       6768
# user_score         6768
# rating             5553
# dtype: int64

# %%
len(data)
# Out:
# 15316

# %% [markdown]
# Очень много пропусков! Примерно половина. Заменять нельзя, очень сильно скажется на результе аналитики. </br>

# %%
data[data['rating'].isna()].head()
# Out:
#                              name platform  year_of_release         genre  \
# 6                      Nintendogs       DS             2005    Simulation
# 14  Pokemon Diamond/Pokemon Pearl       DS             2006  Role-Playing
# 17  Pokemon Ruby/Pokemon Sapphire      GBA             2002  Role-Playing
# 19    Pokemon Black/Pokemon White       DS             2010  Role-Playing
# 22      Call of Duty: Black Ops 3      PS4             2015       Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 6       9.05     10.95      1.93         2.74           NaN         NaN    NaN
# 14      6.38      4.46      6.04         1.36           NaN         NaN    NaN
# 17      6.06      3.90      5.38         0.50           NaN         NaN    NaN
# 19      5.51      3.17      5.65         0.80           NaN         NaN    NaN
# 22      6.03      5.86      0.36         2.38           NaN         NaN    NaN

# %% [markdown]
# Пропуски в рейтинге.

# %%
data['rating'].value_counts()
# Out:
# E       3921
# T       2902
# M       1535
# E10+    1392
# EC         8
# K-A        3
# RP         1
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# Основное количество игр относится к рейтингу E,T,M,E10+.
# Последние 4 может убрать, очень редкие.

# %%
data = data.query('~(rating in ["EC","K-A","AO","RP"])')

# %%
data['rating'].value_counts()
# Out:
# E       3921
# T       2902
# M       1535
# E10+    1392
# Name: rating, dtype: int64

# %% [markdown]
# В ходе долгих рассуждений, не придумал  я способ для замены. </br>
# Поскольку этот столбец нам нужен лишь в одном вопросе, то просто будем именно в нём использовать строки без пропусков в столбце rating.

# %% [markdown]
# Суммарные продажи по регионам:

# %%
data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']
# Out:
# /tmp/ipykernel_48/1217879315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# 👍</div>

# %%
data.head()
# Out:
#                     name platform  year_of_release     genre  na_sales  \
# 0             Wii Sports      Wii             2006    Sports     41.36
# 1         Mario Kart Wii      Wii             2008    Racing     15.68
# 2      Wii Sports Resort      Wii             2009    Sports     15.61
# 3  New Super Mario Bros.       DS             2006  Platform     11.28
# 4               Wii Play      Wii             2006      Misc     13.96
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1     12.76      3.79         3.29          82.0         8.3      E
# 2     10.93      3.28         2.95          80.0         8.0      E
# 3      9.14      6.50         2.88          89.0         8.5      E
# 4      9.18      2.93         2.84          58.0         6.6      E
#
#    total_sales
# 0        82.54
# 1        35.52
# 2        32.77
# 3        29.80
# 4        28.91

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       6761
# user_score         6761
# rating             5553
# total_sales           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>Комментарий студента_V.1</h3>
#     Всего 1 дубликат.
# </div>

# %%
data.loc[:,:'genre'].duplicated().sum()
# Out:
# 1

# %%
data = data[~(data.loc[:,:'genre'].duplicated())]

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Т.к. игра однозначно определяется платформой, названием и годом, то можно поискать дубликаты по этому подмножеству</div>

# %% [markdown]
# ### Промежуточный итог: </br>
# Удалось избавиться от части пропусков, но всё равно осталось очень много ~ 50% пропусков в нескольких столбцах. Удалять их не буду, т.к. остались нужные данные в других столбцах, которые тоже надо анализировать. </br>

# %% [markdown]
# <a id='analysis'></a>
# # Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# ### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
data.groupby('year_of_release').agg({'name':'count'}).plot()
plt.title('Количество игр в зависимости от года')
plt.show()

# %% [markdown]
# Количество выходящих игр увеличивалось до 2009 года, после 2009 пошло на спад. </br>
# Говорить о важности данных нужно исходя из поставленной задачи. </br>
# В нашем случае по данным за все периоды можно оценить время жизни игровых платформ, чтобы сказать, в какие платформы лучше не вкладывать средства, из-за их возможного *конца жизни*. Так что да, важны.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Всё верно, чтобы было видно каждый отдельный год, можно сделать так:</div>

# %%
# Код ревьюера
import matplotlib.ticker as ticker

fig, ax = plt.subplots(figsize=(15,6), dpi=150)

data.groupby('year_of_release').agg({'name':'count'}).plot(ax=ax, color='crimson')

ax.set_title('Количество игр в зависимости от года')
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))

plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Можно обратить внимание на разкое изменение после 2012 года</div>

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
group_platform = data.groupby('platform').agg({'total_sales':'sum'}).reset_index().sort_values('total_sales')
group_platform
# Out:
#    platform  total_sales
# 1        DC        15.95
# 11      PSV        53.81
# 13     WiiU        82.19
# 16     XOne       159.32
# 4        GC       196.62
# 5        PC       237.25
# 15       XB       249.61
# 0       3DS       257.81
# 10      PSP       289.53
# 3       GBA       312.88
# 9       PS4       314.14
# 6        PS       719.64
# 2        DS       802.11
# 12      Wii       890.52
# 8       PS3       931.33
# 14     X360       961.24
# 7       PS2      1233.32

# %% [markdown]
# Возьмём последние 6.

# %%
top_six = group_platform['platform'][-6:]

# %%
for platform_name in top_six:
    dataframe = (
                data[data['platform'] == platform_name]
                .groupby(['year_of_release','platform'])
                .agg({'total_sales':'sum'})
                .reset_index()
                )
    dataframe.plot(x='year_of_release',y='total_sales',figsize=(20,5))
    plt.ylim(0,250)
    plt.xticks(dataframe['year_of_release'])
    plt.title(platform_name,fontdict = {'fontsize' : 30})
    plt.show()

# %% [markdown]
# Время жизни: </br>
# PS - 8 лет </br>
# DS - 9 лет </br>
# Wii - 10 лет. </br>
# PS3 - 10 лет.</br>
# X360 - 11 лет.</br>
# PS2 - 11 лет. </br>
# Хоть Wii,PS3,X360 всё ещё продавались в 2016 году, но в очень малом количестве.
# 10 лет - средний срок жизни платформ.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# 👍 В целом 6 платформ может быть удобно на одном графике собрать:</div>

# %%
# Код ревьюера

fig, ax = plt.subplots(figsize=(15,6), dpi=150)
data[data['platform'].isin(top_six)].pivot_table(index='year_of_release',
                                                 columns='platform',
                                                 values='total_sales',
                                                 aggfunc='sum').plot(ax=ax)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))

# %% [markdown]
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.

# %% [markdown]
# Будем брать данные за последние 10 лет. Т.к. платформы в среднем живут 10 лет => игры устаревают за 10 лет.(Новая платформа => повышение технических характеристик => Повышение технической составляющей игры.)

# %% [markdown]
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <h3>👀 Комментарий ревьюера</h3>
#
# Время жизни ты определил верно, но в качестве актуального периода такой срок слишком большой. Платформ хоть и живут 10 лет, но производитель уже на 6-ой год выпускаем новое поколение платформ. С твоим периодом в него попадут больше продажи для неактуальных на 2016 год платформ, что сместит анализ. Нужно взять срок, за который продажи с пика для платформ успевают упасть до низких значений, это 3-4 года</div>

# %% [markdown]
# ### Не учитывайте в работе данные за предыдущие годы.

# %%
# data = data.query('year_of_release >= 2006')

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Возьмём игры после 2012 года. Выделил в data_actual. Ниже везде заменил data на data_actual.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍
# </div>

# %%
data_actual = data.query('year_of_release > 2012')

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %% [markdown]
# Сразу отбросим платформы, на которые перестали выходить игры.

# %%
good_platforms = data_actual.groupby('platform').agg({'year_of_release':'max'}) 
good_platforms = good_platforms.query('year_of_release == 2016').reset_index()
good_platforms = good_platforms['platform']
good_platforms
# Out:
# 0     3DS
# 1      PC
# 2     PS3
# 3     PS4
# 4     PSV
# 5     Wii
# 6    WiiU
# 7    X360
# 8    XOne
# Name: platform, dtype: object

# %% [markdown]
# Теперь посмотрим по возрасту жизни платформ.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid yellow" >
# <h3>!! Комментарий ревьюера</h3>
#
# Тут я тоже чтение поправил. Разумнее было бы `data` не менять, а актуальный период выделить в `data_actual`
# </div>

# %%
try:
    data_for_best_platform = pd.read_csv(r'C:\Users\berya\Downloads\Project_Module_1.csv')

except FileNotFoundError as e:
    print(repr(e))
    data_for_best_platform = pd.read_csv('/datasets/games.csv')

data_for_best_platform.columns = data_for_best_platform.columns.str.lower()
# Out:
# FileNotFoundError(2, 'No such file or directory')

# %%
best_platforms = data_for_best_platform.query('platform in @good_platforms') \
    .groupby('platform').agg({'year_of_release':['min','max',lambda x: x.max() - x.min()]}).reset_index()
best_platforms.columns = ['platform','min','max','lifetime_year']
best_platforms.sort_values('lifetime_year')
# Out:
#   platform     min     max  lifetime_year
# 3      PS4  2013.0  2016.0            3.0
# 8     XOne  2013.0  2016.0            3.0
# 6     WiiU  2012.0  2016.0            4.0
# 0      3DS  2011.0  2016.0            5.0
# 4      PSV  2011.0  2016.0            5.0
# 2      PS3  2006.0  2016.0           10.0
# 5      Wii  2006.0  2016.0           10.0
# 7     X360  2005.0  2016.0           11.0
# 1       PC  1985.0  2016.0           31.0

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Было:
# </div>
#
# <code>
#     for platform_name in best_platforms['platform'].unique():
#     dataframe = (
#                 data_actual[data_actual['platform'] == platform_name]
#                 .groupby(['year_of_release','platform'])
#                 .agg({'total_sales':'sum'})
#                 .reset_index()
#                 )
#     dataframe.plot(x='year_of_release',y='total_sales',figsize=(20,5))
#     plt.ylim(0,250)
#     plt.xticks(dataframe['year_of_release'])
#     plt.title(platform_name,fontdict = {'fontsize' : 30})
#     plt.show()
# </code>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Стало:
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍
# </div>

# %%
fig, ax = plt.subplots(figsize=(15,6), dpi=150)
data_actual[~data_actual['platform'].isin(['PS3','Wii','X360'])].pivot_table(index='year_of_release',
                        columns='platform',
                        values='total_sales',
                        aggfunc='sum').plot(ax=ax)
fig.set_figwidth(10)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))

# %% [markdown]
# PS3,Wii,X360 точно не берём. Близится срок смерти платформы, продажи на нуле. </br>
# PS4, XOne, WiiU,3DS,PSV - достаточно молодые, по уменьшению продаж: </br> PS4 => XOne =>3DS, => PSV/WiiU/PC </br>
# Все платформы падают по количеству продаж. </br>
# Промежуточный вывод: Лучшие потенциально прибыльные платформы: PS4, XOne, PC,3DS, PSV,WiiU

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     PS4 сильно лидирует по количеству продаж! Около 40 млн. в 2016 году!
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Тоже может быть удобно на одном графике собрать</div>

# %% [markdown]
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
best_platforms = ['PS4','XOne','3DS','PSV','WiiU','PC','PS3','Wii','X360']
for_boxplot = data_actual.query('platform in @best_platforms')

# %%
sns.boxplot(data=for_boxplot,x='platform',y='total_sales')
plt.ylim(0,2)
plt.show()

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#      Перестроено в более наглядный вид.
# </div>

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.boxplot(data=for_boxplot,x='platform',y='total_sales',showfliers=False)
plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Чтобы не ставить лимит, можно указать `showfliers=False` и графики сделать больше. `15,6` фигура на мой взгляд хороший выбор. Или можно `stripplot` построить, чтобы видеть выбивающиеся значения:
# </div>

# %%
# Код ревьюера

fig, ax = plt.subplots(figsize=(15,6), dpi=150)

sns.stripplot(data=for_boxplot,x='platform',y='total_sales', color='crimson')
# Out:
# <AxesSubplot:xlabel='platform', ylabel='total_sales'>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Видно, что на некоторых платформах "выстреливших игр" сильно больше</div>

# %%
sns.boxplot(data=for_boxplot,x='platform',y='total_sales')
plt.ylim(0,15)
plt.show()

# %% [markdown]
# Из *ящиков с усами* можно сделать вывод о медианах, количестве выбросов, величине этих выбросов. </br>
# Медианы по total_sales в порядке убывания: XOne => WiiU => PS4 => 3DS => PSV / PC. </br>
# XOne имеет большую медиану, небольшое количество выбросов. </br>
# Видны огромные продажи в виде выбросов у Wii,X360,PS3, но нам эти платформы не интересны. <br>
# Будем смотреть на PS4,XOne,WiiU,PC. <br>
# У PS4 большее количество выбросов от 1,5 млн. до 6 млн., чем у других платформ, также есть несколько игр с продажами 12+ млн.

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     XOne => WiiU/PS4 => 3DS/PC => PSV. PS4 - лучший выбор при анализе глобальных продаж.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍
# </div>

# %% [markdown]
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %% [markdown]
# Возьму Wii.

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Возьму PS4, а то у Wii вышло лишь 23 игры за актуальный период.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍
# </div>

# %%
data_actual['platform'].value_counts()
# Out:
# PS4     392
# PSV     358
# PS3     345
# 3DS     303
# XOne    247
# PC      189
# X360    186
# WiiU    115
# PSP      67
# Wii      23
# DS        8
# Name: platform, dtype: int64

# %%
data_actual['user_score'] = data_actual['user_score'].round(1)
data_actual['critic_score'] = data_actual['critic_score'].round()
# Out:
# /tmp/ipykernel_48/3610262173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_actual['user_score'] = data_actual['user_score'].round(1)
# /tmp/ipykernel_48/3610262173.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_actual['critic_score'] = data_actual['critic_score'].round()

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Было:<br>
# <code>fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(15,6))
# ax[0].scatter(data=data_actual.query('platform == "Wii"'),x='critic_score',y='total_sales')
# ax[1].scatter(data=data_actual.query('platform == "Wii"'),x='user_score',y='total_sales')
# plt.show()</code>
#     </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# Чтобы выше не было предупреждений, можно сделать `data_actual = data.query('year_of_release > 2012');`
# </div>

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(15,6))
ax[0].scatter(data=data_actual.query('platform == "PS4"'),x='critic_score',y='total_sales')
ax[1].scatter(data=data_actual.query('platform == "PS4"'),x='user_score',y='total_sales')
plt.show()

# %%
len(data_actual.query('platform == "Wii"'))
# Out:
# 23

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Лайк за `subplots` 👍 Можно побольше сделать графики
# </div>

# %%
data_actual.query('platform =="PS4"').corr()
# Out:
#                  year_of_release  na_sales  eu_sales  jp_sales  other_sales  \
# year_of_release         1.000000 -0.248961 -0.208306 -0.060993    -0.234796
# na_sales               -0.248961  1.000000  0.785362  0.472981     0.944259
# eu_sales               -0.208306  0.785362  1.000000  0.464563     0.944698
# jp_sales               -0.060993  0.472981  0.464563  1.000000     0.496467
# other_sales            -0.234796  0.944259  0.944698  0.496467     1.000000
# critic_score           -0.022644  0.411824  0.344390  0.321345     0.405953
# user_score              0.153413 -0.021691 -0.049600  0.170206    -0.036360
# total_sales            -0.235032  0.928160  0.958157  0.527129     0.998051
#
#                  critic_score  user_score  total_sales
# year_of_release     -0.022644    0.153413    -0.235032
# na_sales             0.411824   -0.021691     0.928160
# eu_sales             0.344390   -0.049600     0.958157
# jp_sales             0.321345    0.170206     0.527129
# ...

# %% [markdown]
# Из таблицы выше: </br>
# total_sales : critic_score = 0.17 </br>
# total_sales : user_score = 0.12 </br>
# Низкая зависимость между продажами и рейтингами. Довольно неожиданный результат

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Из таблицы выше: </br>
# total_sales : critic_score = 0.40 </br>
# total_sales : user_score = -0.03 </br>
# Слабая зависимость между продажами и рейтингом критиков. НЕт зависимости между продажами и пользовательскими рейтингами.
# </div>

# %% [markdown]
# ### Соотнесите выводы с продажами игр на других платформах.

# %%
for name_platform in data_actual.query('platform in @best_platforms')['platform'].unique():
    fig, ax = plt.subplots(nrows=1,ncols=2)
    print(name_platform)
    ax[0].scatter(data=data_actual[data['platform'] == name_platform],x='critic_score',y='total_sales')
    ax[1].scatter(data=data_actual[data['platform'] == name_platform],x='user_score',y='total_sales')
    plt.show()
# Out:
# PS3
# /tmp/ipykernel_48/840270597.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax[0].scatter(data=data_actual[data['platform'] == name_platform],x='critic_score',y='total_sales')
# /tmp/ipykernel_48/840270597.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ax[1].scatter(data=data_actual[data['platform'] == name_platform],x='user_score',y='total_sales')
# X360
# PS4
# 3DS
# XOne
# WiiU
# Wii
# PC
# PSV

# %%
corr = []
for name_platform in data_actual.query('platform in @best_platforms')['platform'].unique():
    
    koef_critic = data_actual.query('platform == @name_platform')['critic_score'] \
        .corr(data_actual.query('platform == @name_platform')['total_sales'])
    
    koef_user = data_actual.query('platform == @name_platform')['user_score'] \
        .corr(data_actual.query('platform == @name_platform')['total_sales'])
    
    corr.append({'platform':name_platform,'critic_total_corr':koef_critic,'user_total_corr':koef_user})
    
corr = pd.DataFrame(corr)
corr
# Out:
#   platform  critic_total_corr  user_total_corr
# 0      PS3           0.222630         0.005776
# 1     X360           0.252815        -0.011742
# 2      PS4           0.403452        -0.032732
# 3      3DS           0.308324         0.255445
# 4     XOne           0.411342        -0.064178
# 5     WiiU           0.398466         0.413281
# 6      Wii           0.643552         0.682942
# 7       PC           0.208793        -0.095174
# 8      PSV           0.027490         0.001601

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Аккуратно получилось 👍 Можно без цикла сделать так:</div>

# %%
# Код ревьюера

data_actual.groupby('platform')[['user_score','critic_score']].corrwith(data['total_sales']).round(2)
# Out:
# /opt/conda/lib/python3.9/site-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /opt/conda/lib/python3.9/site-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#           user_score  critic_score
# platform
# 3DS             0.26          0.31
# DS               NaN           NaN
# PC             -0.10          0.21
# PS3             0.01          0.22
# PS4            -0.03          0.40
# PSP            -1.00         -1.00
# PSV             0.00          0.03
# Wii             0.68          0.64
# WiiU            0.41          0.40
# X360           -0.01          0.25
# XOne           -0.06          0.41

# %% [markdown]
# Можно сказать, что оценки критиков больше влияют на продажи, чем оценки пользователей. </br>
# До этого я сделал вывод по платформе Wii, но теперь видно, что её показатель корреляции один из самых низких. </br>
# Вывод: Слабая положительная связь между оценкой критиков и количеством продаж есть. Между оценкой пользователей и количеством продаж - практически нет.

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Средняя зависимость наблюдается у Wii, у WiiU слабая зависимость.<br>
#     У остальных платформ зависимости между рейтингом пользователей и продажами практически нет. <br>
#     Чуть большее влияние на продажи оказывает рейтинг критиктов, но зависимость нельзя назвать средней/сильной. <br>
#     PSP показывает значение кофф.корреляции -1, но там почти на 70 строчек лишь у двух есть значения в столбцах с рейтингами.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍 Стоит помнить, что корреляция это близость зависимости к линейной, а не просто бинарный признак есть зависимость / нет зависимости
# </div>

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
data_actual.boxplot(by='genre',column='total_sales',figsize=(15,10))
plt.ylim(0,3)
plt.show()

# %%
data_actual.boxplot(by='genre',column='total_sales',figsize=(15,10))
plt.show()

# %%
genre_count = data_actual.pivot_table(index='genre',aggfunc={'name':'count'}).sort_values('name').reset_index()
genre_count.plot(x='genre',y='name',figsize=(10,5),kind='bar')
plt.title('Количество игр по жанрам')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Медиана больше всего у shooter, platform, sports. Большой межвартильный размах у shooter. </br>
# У жанров sports, racing, platform,misc несколько огромных выбросов. </br>
# Огромное количество игр жанра action, меньше всего игр жанра platform
# Я бы советовал брать жанры: shooter, platform , sports. </br>
# Cамые низкие продажи у Adventure, Puzzle, Strategy

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Всё верно 👍</div>

# %% [markdown]
# <a id='region'></a>
# # Шаг 4. Составьте портрет пользователя каждого региона
# ### Определите для пользователя каждого региона (NA, EU, JP):
# ### Самые популярные платформы (топ-5). Опишите различия в долях продаж.

# %%
top_5_platform = data_actual.groupby('platform').agg({'na_sales':'sum','eu_sales':'sum','jp_sales':'sum'}).reset_index()
top_5_platform['na_sales'] = top_5_platform['na_sales'] / top_5_platform['na_sales'].sum() 
top_5_platform['eu_sales'] = top_5_platform['eu_sales'] / top_5_platform['eu_sales'].sum() 
top_5_platform['jp_sales'] = top_5_platform['jp_sales'] / top_5_platform['jp_sales'].sum() 
top_5_platform
# Out:
#    platform  na_sales  eu_sales  jp_sales
# 0       3DS  0.087272  0.078933  0.481674
# 1        DS  0.001302  0.002167  0.000000
# 2        PC  0.025382  0.064656  0.000000
# 3       PS3  0.145073  0.172883  0.165862
# 4       PS4  0.248429  0.359712  0.113368
# 5       PSP  0.000000  0.000433  0.023370
# 6       PSV  0.011514  0.015552  0.132050
# 7       Wii  0.014987  0.015119  0.000355
# 8      WiiU  0.066734  0.050608  0.077284
# 9      X360  0.186562  0.108406  0.003623
# 10     XOne  0.212744  0.131530  0.002415

# %% [markdown]
# ### Для NA

# %%
top_5_platform.sort_values('na_sales')[-5:].round(2)
# Out:
#    platform  na_sales  eu_sales  jp_sales
# 0       3DS      0.09      0.08      0.48
# 3       PS3      0.15      0.17      0.17
# 9      X360      0.19      0.11      0.00
# 10     XOne      0.21      0.13      0.00
# 4       PS4      0.25      0.36      0.11

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Немного странно выводить снизу вверх топ-5 :) А так, всё здорово 👍 Можно через тот же `subplots` вывести барчарты для каждого региона на одной горизонтали, чтобы место сэкономить</div>

# %%
top_5_platform.plot(x='platform',y='na_sales',kind='bar')
plt.show()

# %% [markdown]
# Топ 5 платформ по количеству проданных игр. <br>
#
# Для NA:
# <ul>
#  <li>X360 - 25%</li>
#  <li>Wii  - 20%</li>
#  <li>PS3  - 16%</li>
#     <li>DS   - 14%</li>
#     <li>PS2   - 5%</li>
#  </ul>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Стало: <br>
# Топ 5 платформ по количеству проданных игр. <br>
#
# Для NA:
# <ul>
#  <li>PS4 - 25%</li>
#  <li>XOne  - 21%</li>
#  <li>X360  - 19%</li>
#     <li>PS3   - 15%</li>
#     <li>3DS   - 9%</li>
#  </ul>
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍
# </div>

# %% [markdown]
# ### Для EU

# %%
top_5_platform.sort_values('eu_sales')[-5:].round(2)
# Out:
#    platform  na_sales  eu_sales  jp_sales
# 0       3DS      0.09      0.08      0.48
# 9      X360      0.19      0.11      0.00
# 10     XOne      0.21      0.13      0.00
# 3       PS3      0.15      0.17      0.17
# 4       PS4      0.25      0.36      0.11

# %%
top_5_platform.plot(x='platform',y='eu_sales',kind='bar')
plt.show()

# %% [markdown]
# Топ 5 платформ по количеству проданных игр. <br>
#
# Для EU:
# <ul>
#  <li>PS3 - 22%</li>
#  <li>X360  - 18%</li>
#  <li>Wii  - 17%</li>
#     <li>DS   - 10%</li>
#     <li>PS4   - 9%</li>
#  </ul>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Cтало: <br>
#     Топ 5 платформ по количеству проданных игр. <br>
#
# Для EU:
# <ul>
#  <li>PS4 - 37%</li>
#  <li>PS3  - 17%</li>
#  <li>XOne  - 13%</li>
#     <li>X360   - 11%</li>
#     <li>3DS   - 8%</li>
#  </ul>
#
# </div>

# %% [markdown]
# ### Для JP

# %%
top_5_platform.sort_values('jp_sales')[-5:].round(2)
# Out:
#   platform  na_sales  eu_sales  jp_sales
# 8     WiiU      0.07      0.05      0.08
# 4      PS4      0.25      0.36      0.11
# 6      PSV      0.01      0.02      0.13
# 3      PS3      0.15      0.17      0.17
# 0      3DS      0.09      0.08      0.48

# %%
top_5_platform.plot(x='platform',y='jp_sales',kind='bar')
plt.show()

# %% [markdown]
# Топ 5 платформ по количеству проданных игр. <br>
#
# Для JP:
# <ul>
#  <li>DS - 25%</li>
#  <li>3DS  - 18%</li>
#  <li>PS3  - 14%</li>
#     <li>PSP   - 13%</li>
#     <li>Wii   - 12%</li>
#  </ul>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Стало: <br>
#     Топ 5 платформ по количеству проданных игр. <br>
#
# Для JP:
# <ul>
#  <li>3DS - 48%</li>
#  <li>PS3  - 17%</li>
#  <li>PSV  - 13%</li>
#     <li>PS4   - 11%</li>
#     <li>WiiU   - 8%</li>
#  </ul>
# </div

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
#
# 👍 Может быть удобно так собрать:
# </div>

# %%
# Код ревьюера

fig, axes = plt.subplots(1,3,figsize=(15,6), dpi=150)

for region, ax, color in zip(['na_sales', 'eu_sales', 'jp_sales'], axes.flat, ['forestgreen','crimson','royalblue']):
    top_5_platform.sort_values(by=region, ascending=False).plot(x='platform', y=region, kind='bar', color=color, ax=ax)

# %% [markdown]
# ### Итог:

# %% [markdown]
# Топ 5 платформ по количеству проданных игр. <br>
# Для NA:
# <ul>
#  <li>X360 - 25%</li>
#  <li>Wii  - 20%</li>
#  <li>PS3  - 16%</li>
#     <li>DS   - 14%</li>
#     <li>PS2   - 5%</li>
#  </ul>
# Для EU:
# <ul>
#  <li>PS3 - 22%</li>
#  <li>X360  - 18%</li>
#  <li>Wii  - 17%</li>
#     <li>DS   - 10%</li>
#     <li>PS4   - 9%</li>
#  </ul>
#  Для JP:
# <ul>
#  <li>DS - 25%</li>
#  <li>3DS  - 18%</li>
#  <li>PS3  - 14%</li>
#     <li>PSP   - 13%</li>
#     <li>Wii   - 12%</li>
#  </ul>
#
# У NA и EU схожие первые 4 платформы по популярности. <br>
# У JP появляется такие платформы как 3DS, PSP

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Стало: <br>
# Топ 5 платформ по количеству проданных игр. <br>
#
# Для NA:
# <ul>
#  <li>PS4 - 25%</li>
#  <li>XOne  - 21%</li>
#  <li>X360  - 19%</li>
#     <li>PS3   - 15%</li>
#     <li>3DS   - 9%</li>
#  </ul>
#     Для EU:
# <ul>
#  <li>PS4 - 37%</li>
#  <li>PS3  - 17%</li>
#  <li>XOne  - 13%</li>
#     <li>X360   - 11%</li>
#     <li>3DS   - 8%</li>
#  </ul>
#     Для JP:
# <ul>
#  <li>3DS - 48%</li>
#  <li>PS3  - 17%</li>
#  <li>PSV  - 13%</li>
#     <li>PS4   - 11%</li>
#     <li>WiiU   - 8%</li>
#  </ul>
#
#     Схожие предпочтения у EU и NA: Платформы PS3,PS4,XOne,X360.
#     У JP С большим отрывом вырывается 3DS.
#
#
#
#
#
#
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Из-за того, что у тебя слишком большой период, можно в портетах заметить уже невыпускающиеся платформы</div>

# %% [markdown]
# ### Самые популярные жанры (топ-5). Поясните разницу.

# %%
top_5_genre = data_actual.groupby('genre').agg({'na_sales':'sum','eu_sales':'sum','jp_sales':'sum'}).reset_index()
top_5_genre['na_sales'] = top_5_genre['na_sales'] / top_5_genre['na_sales'].sum() 
top_5_genre['eu_sales'] = top_5_genre['eu_sales'] / top_5_genre['eu_sales'].sum() 
top_5_genre['jp_sales'] = top_5_genre['jp_sales'] / top_5_genre['jp_sales'].sum() 
top_5_genre
# Out:
#            genre  na_sales  eu_sales  jp_sales
# 0         Action  0.287976  0.301175  0.287612
# 1      Adventure  0.016312  0.021034  0.041341
# 2       Fighting  0.035526  0.021798  0.054340
# 3           Misc  0.062804  0.051092  0.065350
# 4       Platform  0.041443  0.039722  0.034025
# 5         Puzzle  0.001896  0.002550  0.008382
# 6         Racing  0.029609  0.051475  0.016338
# 7   Role-Playing  0.106006  0.094256  0.362551
# 8        Shooter  0.250714  0.224001  0.046953
# 9     Simulation  0.011103  0.027841  0.032107
# 10        Sports  0.149117  0.154297  0.038429
# 11      Strategy  0.007494  0.010759  0.012573

# %% [markdown]
# ### Для NA

# %%
top_5_genre.sort_values('na_sales')[-5:].round(2)
# Out:
#            genre  na_sales  eu_sales  jp_sales
# 3           Misc      0.06      0.05      0.07
# 7   Role-Playing      0.11      0.09      0.36
# 10        Sports      0.15      0.15      0.04
# 8        Shooter      0.25      0.22      0.05
# 0         Action      0.29      0.30      0.29

# %%
top_5_genre.plot(x='genre',y='na_sales',kind='bar')
plt.show()

# %% [markdown]
# ### Для EU

# %%
top_5_genre.sort_values('eu_sales')[-5:].round(2)
# Out:
#            genre  na_sales  eu_sales  jp_sales
# 6         Racing      0.03      0.05      0.02
# 7   Role-Playing      0.11      0.09      0.36
# 10        Sports      0.15      0.15      0.04
# 8        Shooter      0.25      0.22      0.05
# 0         Action      0.29      0.30      0.29

# %%
top_5_genre.plot(x='genre',y='eu_sales',kind='bar')
plt.show()

# %% [markdown]
# ### Для JP

# %%
top_5_genre.sort_values('jp_sales')[-5:].round(2)
# Out:
#           genre  na_sales  eu_sales  jp_sales
# 8       Shooter      0.25      0.22      0.05
# 2      Fighting      0.04      0.02      0.05
# 3          Misc      0.06      0.05      0.07
# 0        Action      0.29      0.30      0.29
# 7  Role-Playing      0.11      0.09      0.36

# %%
top_5_genre.plot(x='genre',y='jp_sales',kind='bar')
plt.show()

# %% [markdown]
# ### Итог:

# %% [markdown]
# Топ 5 жанров по регионам.
#
# Для NA:
# <ul>
#  <li>Action         - 22%</li>
#  <li>Sports         - 17%</li>
#  <li>Shooter        - 16%</li>
#  <li>Misc           - 12%</li>
#  <li>Role-Playing   - 8%</li>
#  </ul>
#  Для EU:
# <ul>
#  <li>Action         - 23%</li>
#  <li>Sports         - 17%</li>
#  <li>Shooter        - 16%</li>
#  <li>Misc           - 10%</li>
#  <li>Racing   - 8%</li>
#  </ul>
#  Для JP:
# <ul>
#  <li>Role-Playing         - 22%</li>
#  <li>Action         - 17%</li>
#  <li>Misc        - 16%</li>
#  <li>Sports           - 12%</li>
#  <li>Platform   - 8%</li>
#  </ul>
#
# Одинаковые топ-4 у NA и EU.
# У JP на первом оказался Role-Playing

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Стало: <br>
#
# Топ 5 жанров по регионам.
#
# Для NA:
# <ul>
#  <li>Action         - 29%</li>
#  <li>Shooter         - 25%</li>
#  <li>Sports        - 15</li>
#  <li>Role-Playing           - 11%</li>
#  <li>Misc   - 6%</li>
#  </ul>
#  Для EU:
# <ul>
#  <li>Action         - 30%</li>
#  <li>Shooter         - 22%</li>
#  <li>Sports        - 15%</li>
#  <li>Role-Playing           - 9%</li>
#  <li>Racing   - 5%</li>
#  </ul>
#  Для JP:
# <ul>
#  <li>Role-Playing         - 36%</li>
#  <li>Action         - 29%</li>
#  <li>Misc        - 7%</li>
#  <li>Fighting           - 5%</li>
#  <li>Shooter   - 5%</li>
#  </ul>
#
#     Вновь похожие вкусы у EU и NA, JP на их фоне выделяется популярностью жанра Role-Playing.
# </div>

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Добавил строку ниже для замены пропусков
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
# Если ты думаешь, что `data_esrb = data_actual` создает копию, то нет. Изменяя `data_esrb` ты изменяешь и `data_actual`., Чтобы сделать копию, надо `data_esrb = data_actual.copy()`
#
# </div>

# %%
data_esrb = data_actual
data_esrb['rating'] = data_esrb['rating'].fillna('Unknown')
data_esrb
# Out:
# /tmp/ipykernel_48/1791994420.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_esrb['rating'] = data_esrb['rating'].fillna('Unknown')
#                                 name platform  year_of_release         genre  \
# 11                Grand Theft Auto V      PS3             2013        Action
# 15                Grand Theft Auto V     X360             2013        Action
# 22         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 24               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 33                Grand Theft Auto V      PS4             2014        Action
# ...                              ...      ...              ...           ...
# ...

# %%
some = data_esrb.groupby('rating').agg({'na_sales':'sum','eu_sales':'sum','jp_sales':'sum'}).reset_index()

# %%
some['na_sales'] = some['na_sales'] / some['na_sales'].sum()
some['eu_sales'] = some['eu_sales'] / some['eu_sales'].sum()
some['jp_sales'] = some['jp_sales'] / some['jp_sales'].sum()
some
# Out:
#     rating  na_sales  eu_sales  jp_sales
# 0        E  0.180599  0.212528  0.107544
# 1     E10+  0.123918  0.108839  0.041838
# 2        M  0.377442  0.370497  0.100227
# 3        T  0.113751  0.106953  0.146257
# 4  Unknown  0.204291  0.201183  0.604134

# %%
some.plot(x='rating',kind='bar')
plt.show()

# %% [markdown]
# У NA и EU примерно одинаковые показатели.
# В Японии меньше игр рейтинга M, Больше игр рейтинга T

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     У NA и EU примерно одинаковые показатели. <br>
#     В JP теперь 60% игр без рейтинга!!!
# </div

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
# Да, это опять же может быть связано с тем, что в Японии есть свой аналог ESRB. Это не позволяет ранжировать рейтинги по популярности, но показывает, что в Японии любят всё японское
# </div>

# %% [markdown]
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <h3>👀 Комментарий ревьюера</h3>
#
# Хорошая визуализация 👍 Тут надо вспомнить, что в столбце с рейтингом было много пропусков. Чтобы увидеть количество продажи для игр без рейтинга по регионам, нужно заполнить пропуски маркером и посмотерть на график выше. Это может подчеркнуть различия между регионами
# </div>

# %% [markdown]
# ### Вывод:
# Регионы EU и NA схожи в предпочтениях как в платформах, так и в жанрах. </br>
# Регион JP несколько отличается, большая популярность платформы 3DS (в EU и NA этой платформы нет в топ-5), также популярность у жанра Role-Playing ( в EU не входит в топ-5, в NA на 5-м месте)

# %% [markdown]
# <a id='hypothesis'></a>
# # Шаг 5. Проверьте гипотезы

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;

# %% [markdown]
# Двусторонняя гипотеза: </br>
# Нулевая гипотеза: H0: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые. user_score_xbox == user_score_pc </br>
# Альтернативная гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC НЕ одинаковые. user_score_xbox != user_score_pc</br>
# Возьму уровень статистической значимости alpha = 0.05

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Гипотезы сформулированы верно 👍</div>

# %% [markdown]
# Посмотрю количество игр на XBox One и PC, чтобы понять какой параметр брать equal_var = True или equal_var = False для метода scipy.stats.ttest_ind (array1, array2, equal_var)

# %%
user_score_xbox = data_actual.loc[(data['platform'] == "XOne") & ~(data_actual['user_score'].isna()),'user_score']
user_score_pc   = data_actual.loc[(data['platform'] == "PC") & ~(data_actual['user_score'].isna()),'user_score']
alpha = 0.05

# %%
len(user_score_xbox)
# Out:
# 186

# %%
len(user_score_pc)
# Out:
# 156

# %% [markdown]
# Т.к. выборки разного размера, equal_var = False.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Это конечно не самый мощный критерий для определения равенства дисперсий, но на практике можно почти всегда указывать `equal_var=False`, так тест ведёт себя в общем случае лучше. Можно тут табличку посмотреть на эту тему: https://ru.wikipedia.org/wiki/T-%D0%BA%D1%80%D0%B8%D1%82%D0%B5%D1%80%D0%B8%D0%B9_%D0%A3%D1%8D%D0%BB%D1%87%D0%B0#:~:text=t%2D%D0%BA%D1%80%D0%B8%D1%82%D0%B5%D1%80%D0%B8%D0%B9%20%D0%A3%D1%8D%D0%BB%D1%87%D0%B0%20%E2%80%94%20%D1%82%D0%B5%D1%81%D1%82%2C,%D0%AF%D0%B2%D0%BB%D1%8F%D0%B5%D1%82%D1%81%D1%8F%20%D0%BC%D0%BE%D0%B4%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D0%B5%D0%B9%20t%2D%D0%BA%D1%80%D0%B8%D1%82%D0%B5%D1%80%D0%B8%D1%8F%20%D0%A1%D1%82%D1%8C%D1%8E%D0%B4%D0%B5%D0%BD%D1%82%D0%B0.</div>

# %%
results = st.ttest_ind (user_score_xbox, user_score_pc, equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.16549790539028733
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Принимаем альтернативную гипотезу. Средние пользовательские рейтинги платформ Xbox One и PC НЕ одинаковые.

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Принимаю нулевую гипотезу. Средние пользовательские рейтинги платформ XBox One и PC одинаковые.
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
# Формально, цель теста это именно нулевую гипотезу отвергнуть. Если этого сделать не получается, то её не принимают, а пишут, что отвергнуть не удалось. Можно на эту тему почитать последний абзац тут: https://allatambov.github.io/psms/pdf/hypo-test.pdf</div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Результат может поменяться, т.к. сейчас в выборке много исторических данных для PC</div>

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# Двусторонняя гипотеза: </br>
# Нулевая гипотеза: H0: Средние пользовательские рейтинги жанров Action и Sports одинаковые. action_score == sports_score</br>
# Альтернативная гипотеза: Средние пользовательские рейтинги жанров Action и Sports разные. action_score != sports_score </br>
# Возьму уровень статистической значимости alpha = 0.05

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# Гипотезы тоже сформулированы верно 👍</div>

# %% [markdown]
# Посмотрю количество игр жанров Action и Sports, чтобы понять какой параметр брать equal_var = True или equal_var = False для метода scipy.stats.ttest_ind (array1, array2, equal_var)

# %%
action_score = data_actual.loc[(data['genre'] == "Action") & ~(data['user_score'].isna()),'user_score']
sports_score = data_actual.loc[(data['genre'] == "Sports") & ~(data['user_score'].isna()),'user_score']
alpha = 0.05

# %%
len(action_score)
# Out:
# 393

# %%
len(sports_score)
# Out:
# 162

# %% [markdown]
# Т.к. выборки разного размера, equal_var = False.

# %%
results = st.ttest_ind (action_score, sports_score, equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 4.957003937818579e-21
# Отвергаем нулевую гипотезу

# %% [markdown]
# Принимаем альтернативную гипотезу. Средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# ### Поясните: </br>
# Как вы сформулировали нулевую и альтернативную гипотезы; </br>
# Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# H0 всегда формулируется так, чтобы использовать знак равенства. H1 - противоположна H0. </br>
# Поскольку здесь Гипотеза о равенстве средних двух генеральных совокупностей, применял ttest_ind.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# 👍
#
# >  Поскольку здесь Гипотеза о равенстве средних двух генеральных совокупностей, применял ttest_ind.
#
# Стоит отметить, что сравнивается средние двух **независимых** совопкупностей
# </div>

# %% [markdown]
# # Шаг 6. Напишите общий вывод

# %% [markdown]
# #### Цель анализа была определить закономерности, определяющие успешность игры.
# #### Предобработка. <br>
# Исследование началось с обработки данных. Пришлось оставить большое количество пропусков в столбцах: user_score,critic_score,rating. Пропуски нельзя было заменить из-за их количества (примерно 50% в каждом столбце). Удалять строки с пропусками в этих столбцах было нецелесообразно, т.к. имелись данные в других столбцах, также важные для исследования. <br>
# #### Анализ. <br>
#
# Во-первых, была выведена средняя продолжительность жизни платформ, которая составялет ~10 лет. Из этих рассуждений я взял данные исследования 10 лет. <br>
# Лучшие платформы выбирались по нескольким критериям: Сколько лет существует платформа, количество продаж, также был построен *ящик с усами*, где я смотрел на межквартильные размахи, медианы, количество выбросов и насколько эти выбросы большие. <br>
# Рекомендуемые платформы: XOne,PS4,WiiU,PC. Межквартильные размахи примерно равные.(кроме PC)
# <ul>
#     <li>
#         XOne - 3 года. Медиана по количеству продаж в мире ~ 25000.
#     </li>
#     <li>
#         PS4 - 3 года. Медиана по количеству продаж в мире ~ 20000. У PS4 большее количество выбросов от 1,5 млн. до 6 млн.         , чем у других платформ, также есть несколько игр с продажами 12+ млн.
#     </li>
#     <li>
#         WiiU - 4 года. Медиана по количеству продаж в мире ~  25000.
#     </li>
#     <li>
#         PC - 31 год. Медиана по количеству продаж в мире ~ 8000. Меньший межквартальный размах, чем у остальных платформ. Платформа существует уже 31 год, неизвестно сколько ещё будет жить. Плюс в том, что PC используется не только для игр => у многих людей есть PC, если они захотят провести немного времени за играми, то вряд ли будут брать специально игровую платформу.
#     </li>
# </ul>
# <br>
# Выяснил, что пользовательский рейтинг почти не влияет на количество продаж. Рейтинг критиков имеет небольшое влияние.<br>
#
# Медиана больше всего у shooter, platform, sports. Большой межвартильный размах у shooter. </br>
# У жанров sports, racing, platform,misc несколько огромных выбросов. </br>
# Огромное количество игр жанра action, меньше всего игр жанра platform
# Я бы советовал брать жанры: shooter, platform , sports. </br>
# Cамые низкие продажи у Adventure, Puzzle, Strategy <br>
#
# #### Разбивка по регионам.
# Если идёт цель на определенный регион, то надо знать его предпочтения.
#
# Топ 5 жанров по регионам.
#
# Для NA:
# <ul>
#  <li>Action         - 22%</li>
#  <li>Sports         - 17%</li>
#  <li>Shooter        - 16%</li>
#  <li>Misc           - 12%</li>
#  <li>Role-Playing   - 8%</li>
#  </ul>
#  Для EU:
# <ul>
#  <li>Action         - 23%</li>
#  <li>Sports         - 17%</li>
#  <li>Shooter        - 16%</li>
#  <li>Misc           - 10%</li>
#  <li>Racing   - 8%</li>
#  </ul>
#  Для JP:
# <ul>
#  <li>Role-Playing         - 22%</li>
#  <li>Action         - 17%</li>
#  <li>Misc        - 16%</li>
#  <li>Sports           - 12%</li>
#  <li>Platform   - 8%</li>
#  </ul>
#
# Одинаковые топ-4 у NA и EU.
# У JP на первом оказался Role-Playing<br>
#
# Топ 5 платформ по количеству проданных игр. <br>
# Для NA:
# <ul>
#  <li>X360 - 25%</li>
#  <li>Wii  - 20%</li>
#  <li>PS3  - 16%</li>
#     <li>DS   - 14%</li>
#     <li>PS2   - 5%</li>
#  </ul>
# Для EU:
# <ul>
#  <li>PS3 - 22%</li>
#  <li>X360  - 18%</li>
#  <li>Wii  - 17%</li>
#     <li>DS   - 10%</li>
#     <li>PS4   - 9%</li>
#  </ul>
#  Для JP:
# <ul>
#  <li>DS - 25%</li>
#  <li>3DS  - 18%</li>
#  <li>PS3  - 14%</li>
#     <li>PSP   - 13%</li>
#     <li>Wii   - 12%</li>
#  </ul>
#
# У NA и EU схожие первые 4 платформы по популярности. <br>
# У JP появляется такие платформы как 3DS, PSP <br>
#
#
# Регионы EU и NA схожи в предпочтениях как в платформах, так и в жанрах. </br>
# Регион JP несколько отличается, большая популярность платформы 3DS (в EU и NA этой платформы нет в топ-5), также популярность у жанра Role-Playing ( в EU не входит в топ-5, в NA на 5-м месте) <br>
# Также стоит обратить внимание на рейтинг ESRB. Количество игр(в процентом соотношении от общего количества игр в данном регионе)возрастного рейтинга:
# <ul>
#  <li>E,E10+ приблизительно равно во всех трёх регионах.</li>
#  <li>Рейтинг M - EU~NA, в JP меньше процентов на 10.</li>
#  <li>Рейтинг T - JP больше процентов на 10</li>
#  </ul>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера</h3>
#
# В целом хорошая работа 👍 После корректировки актуального периода нужно будет поправить выводы, которые изменятся</div>

# %% [markdown]
# <div class = "alert alert-info" style="border-left: 7px solid blue">
# <h3>✔ Комментарий студента_V.1</h3>
#     Поменялись топы по платформам и по жанрам:
#     Топ 5 платформ по количеству проданных игр. <br>
#
# Для NA:
# <ul>
#  <li>PS4 - 25%</li>
#  <li>XOne  - 21%</li>
#  <li>X360  - 19%</li>
#     <li>PS3   - 15%</li>
#     <li>3DS   - 9%</li>
#  </ul>
#     Для EU:
# <ul>
#  <li>PS4 - 37%</li>
#  <li>PS3  - 17%</li>
#  <li>XOne  - 13%</li>
#     <li>X360   - 11%</li>
#     <li>3DS   - 8%</li>
#  </ul>
#     Для JP:
# <ul>
#  <li>3DS - 48%</li>
#  <li>PS3  - 17%</li>
#  <li>PSV  - 13%</li>
#     <li>PS4   - 11%</li>
#     <li>WiiU   - 8%</li>
#  </ul>
#
#     Топ 5 жанров по регионам.
#
# Для NA:
# <ul>
#  <li>Action         - 29%</li>
#  <li>Shooter         - 25%</li>
#  <li>Sports        - 15</li>
#  <li>Role-Playing           - 11%</li>
#  <li>Misc   - 6%</li>
#  </ul>
#  Для EU:
# <ul>
#  <li>Action         - 30%</li>
#  <li>Shooter         - 22%</li>
#  <li>Sports        - 15%</li>
#  <li>Role-Playing           - 9%</li>
#  <li>Racing   - 5%</li>
#  </ul>
#  Для JP:
# <ul>
#  <li>Role-Playing         - 36%</li>
#  <li>Action         - 29%</li>
#  <li>Misc        - 7%</li>
#  <li>Fighting           - 5%</li>
#  <li>Shooter   - 5%</li>
#  </ul>
#
# Оказалось, что 60% игр, 60% игр в JP, не имеют рейтинга (по крайней мере в наших данных так) <br>
# Оказалось, что коэфф.корреляции между продажами и рейтнгами у платформы WiiU составляет ~ 0.4. Зависимость хоть и не сильная, но она больше, чем у остальных платформ. <br>
# По жанрам ситуация не сильно изменилась. Всё также Action в топе регионов. Но теперь появился жанр Role-Playing в EU и NA, целых 10% от количества продаж. <br>
#     Учитывая количество продаж жанра Action, можно брать количеством игр данного жанра, а не высокой ценой.
# Очень популярная платформа в JP : 3DS, точно следует обратить внимание на эту платформу, если пытаться закрепиться на этом рынке.
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <h3>✔ Комментарий ревьюера V.2</h3>
#
# 👍</div>
